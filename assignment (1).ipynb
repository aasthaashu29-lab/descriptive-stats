# %% [markdown]
# # **Descriptive Statistics**

# %% [markdown]
# Q1.A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why? **bold text**
#
#   ->Mean (Average)
# Mean= 10+12+11+15+14+13+12/7=87/7=12.43
#
# Median
# Ordering the data:
# [10, 11, 12, 12, 13, 14, 15] → Median = 12
#
# The bakery's weekly sales are best represented by an average of about 12.4 dozens per day,because it reflects all daily sales and the data is fairly consistent without outliners.
#
#
# Q2.A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance? **bold text**
#     ->Let’s calculate the mean score:
# Step 1: Add all the marks
#
# 12 + 15 + 14 + 16 + 18 + 20 + 19 = 114
#
# Step 2: Divide by the number of students
#
# There are 7 scores.
# Mean = 114/7 =16.286
# The class performed well overall, with an average score of about 16.3.
#
# Q3.A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
#
# **bold text**
#     ->Let’s find the mode of the shoe sizes sold.
#
# Step 1: Identify the frequency of each size
# 	•	Size 7 → 2 times
# 	•	Size 8 → 3 times
# 	•	Size 9 → 2 times
# 	•	Size 10 → 1 time
#
# Mode
#
# Mode = 8 (the size that appears most frequently)
# The mode is 8, and it helps the store manager stock more of the most popular size to meet customer demand.
#
# Q4.A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median.
# **bold text**
#
#       ->Let’s analyze the data:
# Used car prices:
#  [$8,000, $9,500, $10,200, $11,000, $50,000]
#
# The median better than the mean here because $50,000 is an outlier — much higher than the other prices.
# Calculate the Median
#
# Sorted data:
# $8,000, $9,500, $10,200, $11,000, $50,000
#
# The middle value (3rd value in 5 numbers):
# Median = $10,200
#
# Q5.A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time? **bold text**
#
#
#      ->Step 1: Identify highest and lowest times
# 	•	Highest time = 40 minutes
# 	•	Lowest time = 25 minutes
#
# Step 2: Calculate the range
# Range = 40 - 25 = 15 minutes
#
# The 15-minute range shows that the student’s puzzle-solving time changes noticeably across the week.
#
# Q6.A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging? **bold text**
#
#     ->Let’s find the range of the apple weights.
#
# Step 1: Highest and lowest values
# 	•	Highest = 120 kg
# 	•	Lowest = 98 kg
#
# Step 2: Calculate the range
#
# Range = 120 - 98 = 22 kg
# A 22 kg range helps the farmer prepare for weeks with varying harvest sizes and plan packaging accordingly.
#
# Q7.Two delivery companies track delivery delays (in minutes).
#
# Company A: variance = 6
#
# Company B: variance = 15
#  Which company is more consistent, and why? **bold text**
#
#     ->Company A is more consistent because:
#
# Variance measures how spread out the data is from the mean:
# 	•	Lower variance = more consistency
# 	•	Higher variance = more fluctuation
#
# Here:
# 	•	Company A variance = 6 → smaller spread → delivery times are more stable
# 	•	Company B variance = 15 → larger spread → delivery times vary more
# Company A is more consistent because it has a lower variance, meaning its delivery delays fluctuate less.
#
# Q8.A finance student compares the daily price fluctuations of two cryptocurrencies.
#
# Coin A: standard deviation = $30
#
# Coin B: standard deviation = $120
#  Which coin is riskier to invest in, and why? **bold text**
#
#     ->Coin B is riskier to invest in.
#
# Standard deviation measures volatility — how much the price moves away from its average.
# 	•	Coin A: $30 → smaller fluctuations → more stable
# 	•	Coin B: $120 → much larger fluctuations → highly unpredictable
#
# Coin B is riskier because its higher standard deviation ($120) shows much greater volatility in daily prices, meaning the value can change sharply and unpredictably.
#
# Q9.A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410]
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern? **bold text**
#
#     ->Mean electricity usage =
#    mean = 400+420+390+450+410/5=2070/5=414kWh
#    standard deviation =20.6kWh
#    The family's energy use pattern is steady with only small variaions around an average of 414kwh per month.
#
#    Q10.A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance **bold text**?
#
#     ->Here are all the statistical measures for the player’s scores:
#
# Scores: [15, 18, 20, 22, 25, 17, 19, 21]
#  1. Mean (Average)
# 157/8=19.625
# 2. Median
#
# Sorted scores: [15, 17, 18, 19, 20, 21, 22, 25]
#
# Middle two values are 19 and 20:
# Median: 19+20/2 =19.5
# 3.There is no repeating value so mode none
# 4.Range =25-15=10
# 5.Using the scores, the standard deviation = 2.91
# The player is a consistent scorer, usually putting up around 19–20 points per game with only small variations. This kind of reliability is valuable for a team since his performance can be predicted and counted on each game.
